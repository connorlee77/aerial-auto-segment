# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
x = cv2.imread('/home/connor/repos/aerial-auto-segment/autoseg_vfm/aerial_autoseg_outputs/most_common/odise/2023-03-XX_Duck/ONR_2023-03-21-09-59-39/mask/pair-00000.png', -1)

# %%
plt.imshow(x)

# %%
np.unique(x)
# Out:
# array([0], dtype=uint8)
